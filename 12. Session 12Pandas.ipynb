# %% [markdown]
# ## Pandas
# - Pandas is a fast, powerful ans easy to use open source library for data analysis and manipulation
# 1. Series
# 2. DataFrame

# %%
import numpy as np
import pandas as pd

# %%
employee1 = pd.Series({'Name' : 'Utkarsh', 'ID' : 1, 'Gender' : 'Male', 'Salary':95000})
employee2 = pd.Series({'Name' : 'Kartik', 'ID' : 2, 'Gender' : 'Male','Salary':85000})
employee3 = pd.Series({'Name' : 'Aishwarya', 'ID' : 3, 'Gender' : 'Female','Salary':75000})
employee4 = pd.Series({'Name' : 'Anand', 'ID' : 4, 'Gender' : 'Male','Salary':65000})
employee5 = pd.Series({'Name' : 'Shalini', 'ID' : 5, 'Gender' : 'Female','Salary':90000})
employee6 = pd.Series({'Name' : 'Pratik', 'ID' : 6, 'Gender' : 'Male','Salary':80000})
employee7 = pd.Series({'Name' : 'Monalika', 'ID' : 7, 'Gender' : 'Female','Salary':70000})
employee8 = pd.Series({'Name' : 'Ayesha', 'ID' : 8, 'Gender' : 'Female','Salary':60000})
employee9 = pd.Series({'Name' : 'Anant', 'ID' : 9, 'Gender' : 'Male','Salary':100000})
employee10 = pd.Series({'Name' : 'Shamiksha', 'ID' : 10, 'Gender' : 'Female','Salary':45000})
employee11 = pd.Series({'Name' : 'Prashant', 'ID' : 11, 'Gender' : 'Male','Salary':55000})
employee12 = pd.Series({'Name' : 'Mohini', 'ID' : 12, 'Gender' : 'Female','Salary':65000})

# %%
employee1
# Out:
# Name      Utkarsh
# ID              1
# Gender       Male
# Salary      95000
# dtype: object

# %%
employees = [employee1, employee2, employee3, employee4, employee5, employee6, employee7, employee8, employee9, employee10, employee11, employee12]
df1 = pd.DataFrame(data = employees, index = range(101, 113))
df1
# Out:
#           Name  ID  Gender  Salary
# 101    Utkarsh   1    Male   95000
# 102     Kartik   2    Male   85000
# 103  Aishwarya   3  Female   75000
# 104      Anand   4    Male   65000
# 105    Shalini   5  Female   90000
# 106     Pratik   6    Male   80000
# 107   Monalika   7  Female   70000
# 108     Ayesha   8  Female   60000
# 109      Anant   9    Male  100000
# 110  Shamiksha  10  Female   45000
# 111   Prashant  11    Male   55000
# 112     Mohini  12  Female   65000

# %%
df1.head()
# Out:
#           Name  ID  Gender  Salary
# 101    Utkarsh   1    Male   95000
# 102     Kartik   2    Male   85000
# 103  Aishwarya   3  Female   75000
# 104      Anand   4    Male   65000
# 105    Shalini   5  Female   90000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 101 to 112
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    12 non-null     object
#  1   ID      12 non-null     int64
#  2   Gender  12 non-null     object
#  3   Salary  12 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 516.0+ bytes

# %%
df1.index
# Out:
# RangeIndex(start=101, stop=113, step=1)

# %%
df1.values
# Out:
# array([['Utkarsh', 1, 'Male', 95000],
#        ['Kartik', 2, 'Male', 85000],
#        ['Aishwarya', 3, 'Female', 75000],
#        ['Anand', 4, 'Male', 65000],
#        ['Shalini', 5, 'Female', 90000],
#        ['Pratik', 6, 'Male', 80000],
#        ['Monalika', 7, 'Female', 70000],
#        ['Ayesha', 8, 'Female', 60000],
#        ['Anant', 9, 'Male', 100000],
#        ['Shamiksha', 10, 'Female', 45000],
#        ['Prashant', 11, 'Male', 55000],
#        ['Mohini', 12, 'Female', 65000]], dtype=object)

# %%
df1.columns
# Out:
# Index(['Name', 'ID', 'Gender', 'Salary'], dtype='object')

# %%
df1.name = 'Employees'
df1.index.name = 'Employee_ID'

# %%
df1.name
# Out:
# 'Employees'

# %%
df1.index.name
# Out:
# 'Employee_ID'

# %% [markdown]
# ## Accessing data from a dataframe

# %%
df1['Salary']
# Out:
# Employee_ID
# 101     95000
# 102     85000
# 103     75000
# 104     65000
# 105     90000
# 106     80000
# 107     70000
# 108     60000
# 109    100000
# 110     45000
# 111     55000
# 112     65000
# Name: Salary, dtype: int64

# %%
df1['Name']
# Out:
# Employee_ID
# 101      Utkarsh
# 102       Kartik
# 103    Aishwarya
# 104        Anand
# 105      Shalini
# 106       Pratik
# 107     Monalika
# 108       Ayesha
# 109        Anant
# 110    Shamiksha
# 111     Prashant
# 112       Mohini
# Name: Name, dtype: object

# %%
df1[['Name', 'Salary']]
# Out:
#                   Name  Salary
# Employee_ID
# 101            Utkarsh   95000
# 102             Kartik   85000
# 103          Aishwarya   75000
# 104              Anand   65000
# 105            Shalini   90000
# 106             Pratik   80000
# 107           Monalika   70000
# 108             Ayesha   60000
# 109              Anant  100000
# 110          Shamiksha   45000
# 111           Prashant   55000
# 112             Mohini   65000

# %%
df1.Name
# Out:
# Employee_ID
# 101      Utkarsh
# 102       Kartik
# 103    Aishwarya
# 104        Anand
# 105      Shalini
# 106       Pratik
# 107     Monalika
# 108       Ayesha
# 109        Anant
# 110    Shamiksha
# 111     Prashant
# 112       Mohini
# Name: Name, dtype: object

# %%
df1.Salary
# Out:
# Employee_ID
# 101     95000
# 102     85000
# 103     75000
# 104     65000
# 105     90000
# 106     80000
# 107     70000
# 108     60000
# 109    100000
# 110     45000
# 111     55000
# 112     65000
# Name: Salary, dtype: int64

# %% [markdown]
# ## Accessing Records (Rows)

# %%
df1.loc[101]
# Out:
# Name      Utkarsh
# ID              1
# Gender       Male
# Salary      95000
# Name: 101, dtype: object

# %%
df1.loc[106]
# Out:
# Name      Pratik
# ID             6
# Gender      Male
# Salary     80000
# Name: 106, dtype: object

# %%
df1.iloc[0]
# Out:
# Name      Utkarsh
# ID              1
# Gender       Male
# Salary      95000
# Name: 101, dtype: object

# %%
df1.iloc[1]
# Out:
# Name      Kartik
# ID             2
# Gender      Male
# Salary     85000
# Name: 102, dtype: object

# %%
df1.iloc[-1]
# Out:
# Name      Mohini
# ID            12
# Gender    Female
# Salary     65000
# Name: 112, dtype: object

# %%
df1.loc[[101,105,108]]
# Out:
#                 Name  ID  Gender  Salary
# Employee_ID
# 101          Utkarsh   1    Male   95000
# 105          Shalini   5  Female   90000
# 108           Ayesha   8  Female   60000

# %%
df1.iloc[[0,4,7]]
# Out:
#                 Name  ID  Gender  Salary
# Employee_ID
# 101          Utkarsh   1    Male   95000
# 105          Shalini   5  Female   90000
# 108           Ayesha   8  Female   60000

# %%
df1.loc[101:105]
# Out:
#                   Name  ID  Gender  Salary
# Employee_ID
# 101            Utkarsh   1    Male   95000
# 102             Kartik   2    Male   85000
# 103          Aishwarya   3  Female   75000
# 104              Anand   4    Male   65000
# 105            Shalini   5  Female   90000

# %% [markdown]
# ## Accessing Specific Values

# %%
df1
# Out:
#                   Name  ID  Gender  Salary
# Employee_ID
# 101            Utkarsh   1    Male   95000
# 102             Kartik   2    Male   85000
# 103          Aishwarya   3  Female   75000
# 104              Anand   4    Male   65000
# 105            Shalini   5  Female   90000
# 106             Pratik   6    Male   80000
# 107           Monalika   7  Female   70000
# 108             Ayesha   8  Female   60000
# 109              Anant   9    Male  100000
# 110          Shamiksha  10  Female   45000
# 111           Prashant  11    Male   55000
# 112             Mohini  12  Female   65000

# %%
df1.loc[101]['Salary']
# Out:
# 95000

# %%
df1.loc[105]['Name']
# Out:
# 'Shalini'

# %%
df1.iloc[0]['Salary']
# Out:
# 95000

# %%
df1['Salary'][101]
# Out:
# 95000

# %%
df1.Salary[101]
# Out:
# 95000

# %%
df1.loc[[101,105,108,110]]['Salary']
# Out:
# Employee_ID
# 101    95000
# 105    90000
# 108    60000
# 110    45000
# Name: Salary, dtype: int64

# %%
df1.loc[[101,105,108,110]][['Name', 'Salary']]
# Out:
#                   Name  Salary
# Employee_ID
# 101            Utkarsh   95000
# 105            Shalini   90000
# 108             Ayesha   60000
# 110          Shamiksha   45000

# %%
df1.loc[101 , 'Salary']
# Out:
# 95000

# %%
df1.loc[[101,105,108,110], 'Salary']
# Out:
# Employee_ID
# 101    95000
# 105    90000
# 108    60000
# 110    45000
# Name: Salary, dtype: int64

# %%
df1.loc[[101,105,108,110], ['Name','Salary']]
# Out:
#                   Name  Salary
# Employee_ID
# 101            Utkarsh   95000
# 105            Shalini   90000
# 108             Ayesha   60000
# 110          Shamiksha   45000

# %%
df1.loc[101:105]
# Out:
#                   Name  ID  Gender  Salary
# Employee_ID
# 101            Utkarsh   1    Male   95000
# 102             Kartik   2    Male   85000
# 103          Aishwarya   3  Female   75000
# 104              Anand   4    Male   65000
# 105            Shalini   5  Female   90000

# %%
df1.loc[101:105, 'Salary']
# Out:
# Employee_ID
# 101    95000
# 102    85000
# 103    75000
# 104    65000
# 105    90000
# Name: Salary, dtype: int64

# %% [markdown]
# ----------------
# ----------------

# %% [markdown]
# ## Adding and Deleting Rows and Columns

# %%
df1.loc[113] = ['Priti', 13, 'Female', 71000]
df1
# Out:
#                   Name  ID  Gender  Salary
# Employee_ID
# 101            Utkarsh   1    Male   95000
# 102             Kartik   2    Male   85000
# 103          Aishwarya   3  Female   75000
# 104              Anand   4    Male   65000
# 105            Shalini   5  Female   90000
# 106             Pratik   6    Male   80000
# 107           Monalika   7  Female   70000
# 108             Ayesha   8  Female   60000
# 109              Anant   9    Male  100000
# 110          Shamiksha  10  Female   45000
# 111           Prashant  11    Male   55000
# 112             Mohini  12  Female   65000
# 113              Priti  13  Female   71000

# %%
df1.loc[114] = ['Tarsame', 14, 'Male']
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15904/295648248.py in <module>
# ----> 1 df1.loc[114] = ['Tarsame', 14, 'Male']
#       2 df1
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1722
#    1723             if missing:
# -> 1724                 self._setitem_with_indexer_missing(indexer, value)
#    1725                 return
#    1726
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    2025                     # must have conforming columns
#    2026                     if len(value) != len(self.obj.columns):
# -> 2027                         raise ValueError("cannot set a row with mismatched columns")
#    2028
#    2029                 value = Series(value, index=self.obj.columns, name=indexer)
#
# ValueError: cannot set a row with mismatched columns

# %%
df1['Age'] = np.random.randint(25,50,13)
df1
# Out:
#                   Name  ID  Gender  Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male   95000   25
# 102             Kartik   2    Male   85000   44
# 103          Aishwarya   3  Female   75000   42
# 104              Anand   4    Male   65000   36
# 105            Shalini   5  Female   90000   31
# 106             Pratik   6    Male   80000   46
# 107           Monalika   7  Female   70000   29
# 108             Ayesha   8  Female   60000   32
# 109              Anant   9    Male  100000   32
# 110          Shamiksha  10  Female   45000   37
# 111           Prashant  11    Male   55000   28
# 112             Mohini  12  Female   65000   34
# 113              Priti  13  Female   71000   41

# %%
df1.drop(113, axis = 0)
# Out:
#                   Name  ID  Gender  Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male   95000   25
# 102             Kartik   2    Male   85000   44
# 103          Aishwarya   3  Female   75000   42
# 104              Anand   4    Male   65000   36
# 105            Shalini   5  Female   90000   31
# 106             Pratik   6    Male   80000   46
# 107           Monalika   7  Female   70000   29
# 108             Ayesha   8  Female   60000   32
# 109              Anant   9    Male  100000   32
# 110          Shamiksha  10  Female   45000   37
# 111           Prashant  11    Male   55000   28
# 112             Mohini  12  Female   65000   34

# %%
df1
# Out:
#                   Name  ID  Gender  Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male   95000   25
# 102             Kartik   2    Male   85000   44
# 103          Aishwarya   3  Female   75000   42
# 104              Anand   4    Male   65000   36
# 105            Shalini   5  Female   90000   31
# 106             Pratik   6    Male   80000   46
# 107           Monalika   7  Female   70000   29
# 108             Ayesha   8  Female   60000   32
# 109              Anant   9    Male  100000   32
# 110          Shamiksha  10  Female   45000   37
# 111           Prashant  11    Male   55000   28
# 112             Mohini  12  Female   65000   34
# 113              Priti  13  Female   71000   41

# %%
df1.drop(113, axis = 0, inplace = True)
df1
# Out:
#                   Name  ID  Gender  Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male   95000   25
# 102             Kartik   2    Male   85000   44
# 103          Aishwarya   3  Female   75000   42
# 104              Anand   4    Male   65000   36
# 105            Shalini   5  Female   90000   31
# 106             Pratik   6    Male   80000   46
# 107           Monalika   7  Female   70000   29
# 108             Ayesha   8  Female   60000   32
# 109              Anant   9    Male  100000   32
# 110          Shamiksha  10  Female   45000   37
# 111           Prashant  11    Male   55000   28
# 112             Mohini  12  Female   65000   34

# %%
df1['City'] = ['Jaipur', 'Delhi', 'Chennai', 'Bangalore', 'Jaipur', 'Gurgaon', 'Noida', 'Noida', 'Hyderabad', 'Delhi', 'Jaipur', 'Gurgaon']
df1
# Out:
#                   Name  ID  Gender  Salary  Age       City
# Employee_ID
# 101            Utkarsh   1    Male   95000   25     Jaipur
# 102             Kartik   2    Male   85000   44      Delhi
# 103          Aishwarya   3  Female   75000   42    Chennai
# 104              Anand   4    Male   65000   36  Bangalore
# 105            Shalini   5  Female   90000   31     Jaipur
# 106             Pratik   6    Male   80000   46    Gurgaon
# 107           Monalika   7  Female   70000   29      Noida
# 108             Ayesha   8  Female   60000   32      Noida
# 109              Anant   9    Male  100000   32  Hyderabad
# 110          Shamiksha  10  Female   45000   37      Delhi
# 111           Prashant  11    Male   55000   28     Jaipur
# 112             Mohini  12  Female   65000   34    Gurgaon

# %%
df1['Column'] = 12
df1
# Out:
#                   Name  ID  Gender  Salary  Age       City  Column
# Employee_ID
# 101            Utkarsh   1    Male   95000   25     Jaipur      12
# 102             Kartik   2    Male   85000   44      Delhi      12
# 103          Aishwarya   3  Female   75000   42    Chennai      12
# 104              Anand   4    Male   65000   36  Bangalore      12
# 105            Shalini   5  Female   90000   31     Jaipur      12
# 106             Pratik   6    Male   80000   46    Gurgaon      12
# 107           Monalika   7  Female   70000   29      Noida      12
# 108             Ayesha   8  Female   60000   32      Noida      12
# 109              Anant   9    Male  100000   32  Hyderabad      12
# 110          Shamiksha  10  Female   45000   37      Delhi      12
# 111           Prashant  11    Male   55000   28     Jaipur      12
# 112             Mohini  12  Female   65000   34    Gurgaon      12

# %%
df1.drop('Column', axis = 1, inplace = True)
df1
# Out:
#                   Name  ID  Gender  Salary  Age       City
# Employee_ID
# 101            Utkarsh   1    Male   95000   25     Jaipur
# 102             Kartik   2    Male   85000   44      Delhi
# 103          Aishwarya   3  Female   75000   42    Chennai
# 104              Anand   4    Male   65000   36  Bangalore
# 105            Shalini   5  Female   90000   31     Jaipur
# 106             Pratik   6    Male   80000   46    Gurgaon
# 107           Monalika   7  Female   70000   29      Noida
# 108             Ayesha   8  Female   60000   32      Noida
# 109              Anant   9    Male  100000   32  Hyderabad
# 110          Shamiksha  10  Female   45000   37      Delhi
# 111           Prashant  11    Male   55000   28     Jaipur
# 112             Mohini  12  Female   65000   34    Gurgaon

# %% [markdown]
# ## Querying Based On Condition

# %%
df1
# Out:
#                   Name  ID  Gender  Salary  Age       City
# Employee_ID
# 101            Utkarsh   1    Male   95000   25     Jaipur
# 102             Kartik   2    Male   85000   44      Delhi
# 103          Aishwarya   3  Female   75000   42    Chennai
# 104              Anand   4    Male   65000   36  Bangalore
# 105            Shalini   5  Female   90000   31     Jaipur
# 106             Pratik   6    Male   80000   46    Gurgaon
# 107           Monalika   7  Female   70000   29      Noida
# 108             Ayesha   8  Female   60000   32      Noida
# 109              Anant   9    Male  100000   32  Hyderabad
# 110          Shamiksha  10  Female   45000   37      Delhi
# 111           Prashant  11    Male   55000   28     Jaipur
# 112             Mohini  12  Female   65000   34    Gurgaon

# %%
df1[df1.Age > 40]
# Out:
#                   Name  ID  Gender  Salary  Age     City
# Employee_ID
# 102             Kartik   2    Male   85000   44    Delhi
# 103          Aishwarya   3  Female   75000   42  Chennai
# 106             Pratik   6    Male   80000   46  Gurgaon

# %%
df1[df1.Salary < 75000]
# Out:
#                   Name  ID  Gender  Salary  Age       City
# Employee_ID
# 104              Anand   4    Male   65000   36  Bangalore
# 107           Monalika   7  Female   70000   29      Noida
# 108             Ayesha   8  Female   60000   32      Noida
# 110          Shamiksha  10  Female   45000   37      Delhi
# 111           Prashant  11    Male   55000   28     Jaipur
# 112             Mohini  12  Female   65000   34    Gurgaon

# %%
df1[df1.Salary < 70000][['Name', 'Salary']]
# Out:
#                   Name  Salary
# Employee_ID
# 104              Anand   65000
# 108             Ayesha   60000
# 110          Shamiksha   45000
# 111           Prashant   55000
# 112             Mohini   65000

# %%
df1[df1.City == 'Jaipur']
# Out:
#                  Name  ID  Gender  Salary  Age    City
# Employee_ID
# 101           Utkarsh   1    Male   95000   25  Jaipur
# 105           Shalini   5  Female   90000   31  Jaipur
# 111          Prashant  11    Male   55000   28  Jaipur

# %%
df1[df1.City == 'Jaipur']
# Out:
#                  Name  ID  Gender  Salary  Age    City
# Employee_ID
# 101           Utkarsh   1    Male   95000   25  Jaipur
# 105           Shalini   5  Female   90000   31  Jaipur
# 111          Prashant  11    Male   55000   28  Jaipur

# %%
df1[df1.Salary >= 80000][df1.Salary <= 100000][['Name', 'Salary']]
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_15904/3153781317.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df1[df1.Salary >= 80000][df1.Salary <= 100000][['Name', 'Salary']]
#                 Name  Salary
# Employee_ID
# 101          Utkarsh   95000
# 102           Kartik   85000
# 105          Shalini   90000
# 106           Pratik   80000
# 109            Anant  100000

# %%
df1[df1.Gender == 'Male'][df1.City == 'Jaipur']
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_15904/3948569640.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df1[df1.Gender == 'Male'][df1.City == 'Jaipur']
#                  Name  ID Gender  Salary  Age    City
# Employee_ID
# 101           Utkarsh   1   Male   95000   25  Jaipur
# 111          Prashant  11   Male   55000   28  Jaipur

# %%
df1[(df1.Gender == 'Male') & (df1.City == 'Jaipur')]
# Out:
#                  Name  ID Gender  Salary  Age    City
# Employee_ID
# 101           Utkarsh   1   Male   95000   25  Jaipur
# 111          Prashant  11   Male   55000   28  Jaipur

# %%
df1[(df1.Salary >= 80000) & (df1.Salary <= 100000)][['Name', 'Salary']]
# Out:
#                 Name  Salary
# Employee_ID
# 101          Utkarsh   95000
# 102           Kartik   85000
# 105          Shalini   90000
# 106           Pratik   80000
# 109            Anant  100000

# %%
df1[((df1.City == 'Jaipur') | (df1.City == 'Gurgaon')) & (df1.Age < 40)]      # Not the right way
# Out:
#                  Name  ID  Gender  Salary  Age     City
# Employee_ID
# 101           Utkarsh   1    Male   95000   25   Jaipur
# 105           Shalini   5  Female   90000   31   Jaipur
# 111          Prashant  11    Male   55000   28   Jaipur
# 112            Mohini  12  Female   65000   34  Gurgaon

# %%
df1[(df1.City == 'Jaipur') | (df1.City == 'Gurgaon')][df1.Age < 40]
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_15904/3915641002.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df1[(df1.City == 'Jaipur') | (df1.City == 'Gurgaon')][df1.Age < 40]
#                  Name  ID  Gender  Salary  Age     City
# Employee_ID
# 101           Utkarsh   1    Male   95000   25   Jaipur
# 105           Shalini   5  Female   90000   31   Jaipur
# 111          Prashant  11    Male   55000   28   Jaipur
# 112            Mohini  12  Female   65000   34  Gurgaon

# %%
df1[df1.City == 'Jaipur']['Salary'].mean()
# Out:
# 80000.0

# %%
df1.query('Salary > 80000')
# Out:
#                 Name  ID  Gender  Salary  Age       City
# Employee_ID
# 101          Utkarsh   1    Male   95000   25     Jaipur
# 102           Kartik   2    Male   85000   44      Delhi
# 105          Shalini   5  Female   90000   31     Jaipur
# 109            Anant   9    Male  100000   32  Hyderabad

# %%
df1.query('City == "Jaipur" or City == "Delhi"')[['Name', 'City']]
# Out:
#                   Name    City
# Employee_ID
# 101            Utkarsh  Jaipur
# 102             Kartik   Delhi
# 105            Shalini  Jaipur
# 110          Shamiksha   Delhi
# 111           Prashant  Jaipur

# %%
df1.query('(Salary >=80000 and Salary <= 90000) and Age > 40')
# Out:
#                Name  ID Gender  Salary  Age     City
# Employee_ID
# 102          Kartik   2   Male   85000   44    Delhi
# 106          Pratik   6   Male   80000   46  Gurgaon

# %% [markdown]
# -----
# -----

# %% [markdown]
# ## Important Functions

# %%
df1
# Out:
#                   Name  ID  Gender  Salary  Age       City
# Employee_ID
# 101            Utkarsh   1    Male   95000   25     Jaipur
# 102             Kartik   2    Male   85000   44      Delhi
# 103          Aishwarya   3  Female   75000   42    Chennai
# 104              Anand   4    Male   65000   36  Bangalore
# 105            Shalini   5  Female   90000   31     Jaipur
# 106             Pratik   6    Male   80000   46    Gurgaon
# 107           Monalika   7  Female   70000   29      Noida
# 108             Ayesha   8  Female   60000   32      Noida
# 109              Anant   9    Male  100000   32  Hyderabad
# 110          Shamiksha  10  Female   45000   37      Delhi
# 111           Prashant  11    Male   55000   28     Jaipur
# 112             Mohini  12  Female   65000   34    Gurgaon

# %%
df1.loc[113] = df1.loc[111]
df1.loc[114] = df1.loc[112]

df1.loc[115] = ['Janki', 15, np.nan, 85000, 30, 'Karachi']
df1.loc[116] = ['Pratik', 16, np.nan, np.nan, 42, 'Dholakpur']

df1
# Out:
#                   Name  ID  Gender    Salary  Age       City
# Employee_ID
# 101            Utkarsh   1    Male   95000.0   25     Jaipur
# 102             Kartik   2    Male   85000.0   44      Delhi
# 103          Aishwarya   3  Female   75000.0   42    Chennai
# 104              Anand   4    Male   65000.0   36  Bangalore
# 105            Shalini   5  Female   90000.0   31     Jaipur
# 106             Pratik   6    Male   80000.0   46    Gurgaon
# 107           Monalika   7  Female   70000.0   29      Noida
# 108             Ayesha   8  Female   60000.0   32      Noida
# 109              Anant   9    Male  100000.0   32  Hyderabad
# 110          Shamiksha  10  Female   45000.0   37      Delhi
# 111           Prashant  11    Male   55000.0   28     Jaipur
# 112             Mohini  12  Female   65000.0   34    Gurgaon
# 113           Prashant  11    Male   55000.0   28     Jaipur
# 114             Mohini  12  Female   65000.0   34    Gurgaon
# 115              Janki  15     NaN   85000.0   30    Karachi
# 116             Pratik  16     NaN       NaN   42  Dholakpur

# %%
df1.head()
# Out:
#                   Name  ID  Gender   Salary  Age       City
# Employee_ID
# 101            Utkarsh   1    Male  95000.0   25     Jaipur
# 102             Kartik   2    Male  85000.0   44      Delhi
# 103          Aishwarya   3  Female  75000.0   42    Chennai
# 104              Anand   4    Male  65000.0   36  Bangalore
# 105            Shalini   5  Female  90000.0   31     Jaipur

# %%
df1.head(10)
# Out:
#                   Name  ID  Gender    Salary  Age       City
# Employee_ID
# 101            Utkarsh   1    Male   95000.0   25     Jaipur
# 102             Kartik   2    Male   85000.0   44      Delhi
# 103          Aishwarya   3  Female   75000.0   42    Chennai
# 104              Anand   4    Male   65000.0   36  Bangalore
# 105            Shalini   5  Female   90000.0   31     Jaipur
# 106             Pratik   6    Male   80000.0   46    Gurgaon
# 107           Monalika   7  Female   70000.0   29      Noida
# 108             Ayesha   8  Female   60000.0   32      Noida
# 109              Anant   9    Male  100000.0   32  Hyderabad
# 110          Shamiksha  10  Female   45000.0   37      Delhi

# %%
df1.tail()
# Out:
#                  Name  ID  Gender   Salary  Age       City
# Employee_ID
# 112            Mohini  12  Female  65000.0   34    Gurgaon
# 113          Prashant  11    Male  55000.0   28     Jaipur
# 114            Mohini  12  Female  65000.0   34    Gurgaon
# 115             Janki  15     NaN  85000.0   30    Karachi
# 116            Pratik  16     NaN      NaN   42  Dholakpur

# %%
df1.tail(10)
# Out:
#                   Name  ID  Gender    Salary  Age       City
# Employee_ID
# 107           Monalika   7  Female   70000.0   29      Noida
# 108             Ayesha   8  Female   60000.0   32      Noida
# 109              Anant   9    Male  100000.0   32  Hyderabad
# 110          Shamiksha  10  Female   45000.0   37      Delhi
# 111           Prashant  11    Male   55000.0   28     Jaipur
# 112             Mohini  12  Female   65000.0   34    Gurgaon
# 113           Prashant  11    Male   55000.0   28     Jaipur
# 114             Mohini  12  Female   65000.0   34    Gurgaon
# 115              Janki  15     NaN   85000.0   30    Karachi
# 116             Pratik  16     NaN       NaN   42  Dholakpur

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 101 to 116
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    16 non-null     object
#  1   ID      16 non-null     int64
#  2   Gender  14 non-null     object
#  3   Salary  15 non-null     float64
#  4   Age     16 non-null     int64
#  5   City    16 non-null     object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 896.0+ bytes

# %%
# Check for null (missing) values
df1.isnull().sum()
# Out:
# Name      0
# ID        0
# Gender    2
# Salary    1
# Age       0
# City      0
# dtype: int64

# %%
df1.isna().sum()
# Out:
# Name      0
# ID        0
# Gender    2
# Salary    1
# Age       0
# City      0
# dtype: int64

# %%
df1.Salary.isnull().sum()
# Out:
# 1

# %%
# Check for duplicates
df1.duplicated().sum()
# Out:
# 2

# %%
# Drop duplicates
df1.drop_duplicates(inplace = True)
df1
# Out:
#                   Name  ID  Gender    Salary  Age       City
# Employee_ID
# 101            Utkarsh   1    Male   95000.0   25     Jaipur
# 102             Kartik   2    Male   85000.0   44      Delhi
# 103          Aishwarya   3  Female   75000.0   42    Chennai
# 104              Anand   4    Male   65000.0   36  Bangalore
# 105            Shalini   5  Female   90000.0   31     Jaipur
# 106             Pratik   6    Male   80000.0   46    Gurgaon
# 107           Monalika   7  Female   70000.0   29      Noida
# 108             Ayesha   8  Female   60000.0   32      Noida
# 109              Anant   9    Male  100000.0   32  Hyderabad
# 110          Shamiksha  10  Female   45000.0   37      Delhi
# 111           Prashant  11    Male   55000.0   28     Jaipur
# 112             Mohini  12  Female   65000.0   34    Gurgaon
# 115              Janki  15     NaN   85000.0   30    Karachi
# 116             Pratik  16     NaN       NaN   42  Dholakpur

# %%
df1.nunique()
# Out:
# Name      13
# ID        14
# Gender     2
# Salary    11
# Age       12
# City       9
# dtype: int64

# %%
df1.Gender.nunique()
# Out:
# 2

# %%
df1.Gender.dropna().unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df1.City.unique()
# Out:
# array(['Jaipur', 'Delhi', 'Chennai', 'Bangalore', 'Gurgaon', 'Noida',
#        'Hyderabad', 'Karachi', 'Dholakpur'], dtype=object)

# %%
df1.sort_index()
# Out:
#                   Name  ID  Gender    Salary  Age       City
# Employee_ID
# 101            Utkarsh   1    Male   95000.0   25     Jaipur
# 102             Kartik   2    Male   85000.0   44      Delhi
# 103          Aishwarya   3  Female   75000.0   42    Chennai
# 104              Anand   4    Male   65000.0   36  Bangalore
# 105            Shalini   5  Female   90000.0   31     Jaipur
# 106             Pratik   6    Male   80000.0   46    Gurgaon
# 107           Monalika   7  Female   70000.0   29      Noida
# 108             Ayesha   8  Female   60000.0   32      Noida
# 109              Anant   9    Male  100000.0   32  Hyderabad
# 110          Shamiksha  10  Female   45000.0   37      Delhi
# 111           Prashant  11    Male   55000.0   28     Jaipur
# 112             Mohini  12  Female   65000.0   34    Gurgaon
# 115              Janki  15     NaN   85000.0   30    Karachi
# 116             Pratik  16     NaN       NaN   42  Dholakpur

# %%
df1.sort_index(ascending = False)
# Out:
#                   Name  ID  Gender    Salary  Age       City
# Employee_ID
# 116             Pratik  16     NaN       NaN   42  Dholakpur
# 115              Janki  15     NaN   85000.0   30    Karachi
# 112             Mohini  12  Female   65000.0   34    Gurgaon
# 111           Prashant  11    Male   55000.0   28     Jaipur
# 110          Shamiksha  10  Female   45000.0   37      Delhi
# 109              Anant   9    Male  100000.0   32  Hyderabad
# 108             Ayesha   8  Female   60000.0   32      Noida
# 107           Monalika   7  Female   70000.0   29      Noida
# 106             Pratik   6    Male   80000.0   46    Gurgaon
# 105            Shalini   5  Female   90000.0   31     Jaipur
# 104              Anand   4    Male   65000.0   36  Bangalore
# 103          Aishwarya   3  Female   75000.0   42    Chennai
# 102             Kartik   2    Male   85000.0   44      Delhi
# 101            Utkarsh   1    Male   95000.0   25     Jaipur

# %%
df1.sort_values(by = 'Salary')
# Out:
#                   Name  ID  Gender    Salary  Age       City
# Employee_ID
# 110          Shamiksha  10  Female   45000.0   37      Delhi
# 111           Prashant  11    Male   55000.0   28     Jaipur
# 108             Ayesha   8  Female   60000.0   32      Noida
# 104              Anand   4    Male   65000.0   36  Bangalore
# 112             Mohini  12  Female   65000.0   34    Gurgaon
# 107           Monalika   7  Female   70000.0   29      Noida
# 103          Aishwarya   3  Female   75000.0   42    Chennai
# 106             Pratik   6    Male   80000.0   46    Gurgaon
# 102             Kartik   2    Male   85000.0   44      Delhi
# 115              Janki  15     NaN   85000.0   30    Karachi
# 105            Shalini   5  Female   90000.0   31     Jaipur
# 101            Utkarsh   1    Male   95000.0   25     Jaipur
# 109              Anant   9    Male  100000.0   32  Hyderabad
# 116             Pratik  16     NaN       NaN   42  Dholakpur

# %%
df1.sort_values(by = 'Salary', ascending = False)
# Out:
#                   Name  ID  Gender    Salary  Age       City
# Employee_ID
# 109              Anant   9    Male  100000.0   32  Hyderabad
# 101            Utkarsh   1    Male   95000.0   25     Jaipur
# 105            Shalini   5  Female   90000.0   31     Jaipur
# 102             Kartik   2    Male   85000.0   44      Delhi
# 115              Janki  15     NaN   85000.0   30    Karachi
# 106             Pratik   6    Male   80000.0   46    Gurgaon
# 103          Aishwarya   3  Female   75000.0   42    Chennai
# 107           Monalika   7  Female   70000.0   29      Noida
# 104              Anand   4    Male   65000.0   36  Bangalore
# 112             Mohini  12  Female   65000.0   34    Gurgaon
# 108             Ayesha   8  Female   60000.0   32      Noida
# 111           Prashant  11    Male   55000.0   28     Jaipur
# 110          Shamiksha  10  Female   45000.0   37      Delhi
# 116             Pratik  16     NaN       NaN   42  Dholakpur

# %%
df1.sort_values(by = 'Name')
# Out:
#                   Name  ID  Gender    Salary  Age       City
# Employee_ID
# 103          Aishwarya   3  Female   75000.0   42    Chennai
# 104              Anand   4    Male   65000.0   36  Bangalore
# 109              Anant   9    Male  100000.0   32  Hyderabad
# 108             Ayesha   8  Female   60000.0   32      Noida
# 115              Janki  15     NaN   85000.0   30    Karachi
# 102             Kartik   2    Male   85000.0   44      Delhi
# 112             Mohini  12  Female   65000.0   34    Gurgaon
# 107           Monalika   7  Female   70000.0   29      Noida
# 111           Prashant  11    Male   55000.0   28     Jaipur
# 106             Pratik   6    Male   80000.0   46    Gurgaon
# 116             Pratik  16     NaN       NaN   42  Dholakpur
# 105            Shalini   5  Female   90000.0   31     Jaipur
# 110          Shamiksha  10  Female   45000.0   37      Delhi
# 101            Utkarsh   1    Male   95000.0   25     Jaipur

# %%
df1.sort_values(by = ['Salary', 'Age'])
# Out:
#                   Name  ID  Gender    Salary  Age       City
# Employee_ID
# 110          Shamiksha  10  Female   45000.0   37      Delhi
# 111           Prashant  11    Male   55000.0   28     Jaipur
# 108             Ayesha   8  Female   60000.0   32      Noida
# 112             Mohini  12  Female   65000.0   34    Gurgaon
# 104              Anand   4    Male   65000.0   36  Bangalore
# 107           Monalika   7  Female   70000.0   29      Noida
# 103          Aishwarya   3  Female   75000.0   42    Chennai
# 106             Pratik   6    Male   80000.0   46    Gurgaon
# 115              Janki  15     NaN   85000.0   30    Karachi
# 102             Kartik   2    Male   85000.0   44      Delhi
# 105            Shalini   5  Female   90000.0   31     Jaipur
# 101            Utkarsh   1    Male   95000.0   25     Jaipur
# 109              Anant   9    Male  100000.0   32  Hyderabad
# 116             Pratik  16     NaN       NaN   42  Dholakpur

# %%
pd.concat([df1,df1], axis = 0)
# Out:
#                   Name  ID  Gender    Salary  Age       City
# Employee_ID
# 101            Utkarsh   1    Male   95000.0   25     Jaipur
# 102             Kartik   2    Male   85000.0   44      Delhi
# 103          Aishwarya   3  Female   75000.0   42    Chennai
# 104              Anand   4    Male   65000.0   36  Bangalore
# 105            Shalini   5  Female   90000.0   31     Jaipur
# 106             Pratik   6    Male   80000.0   46    Gurgaon
# 107           Monalika   7  Female   70000.0   29      Noida
# 108             Ayesha   8  Female   60000.0   32      Noida
# 109              Anant   9    Male  100000.0   32  Hyderabad
# 110          Shamiksha  10  Female   45000.0   37      Delhi
# 111           Prashant  11    Male   55000.0   28     Jaipur
# 112             Mohini  12  Female   65000.0   34    Gurgaon
# 115              Janki  15     NaN   85000.0   30    Karachi
# 116             Pratik  16     NaN       NaN   42  Dholakpur
# 101            Utkarsh   1    Male   95000.0   25     Jaipur
# 102             Kartik   2    Male   85000.0   44      Delhi
# 103          Aishwarya   3  Female   75000.0   42    Chennai
# 104              Anand   4    Male   65000.0   36  Bangalore
# 105            Shalini   5  Female   90000.0   31     Jaipur
# 106             Pratik   6    Male   80000.0   46    Gurgaon
# 107           Monalika   7  Female   70000.0   29      Noida
# 108             Ayesha   8  Female   60000.0   32      Noida
# 109              Anant   9    Male  100000.0   32  Hyderabad
# 110          Shamiksha  10  Female   45000.0   37      Delhi
# 111           Prashant  11    Male   55000.0   28     Jaipur
# 112             Mohini  12  Female   65000.0   34    Gurgaon
# 115              Janki  15     NaN   85000.0   30    Karachi
# 116             Pratik  16     NaN       NaN   42  Dholakpur

# %%
pd.concat([df1, df1], axis = 1)
# Out:
#                   Name  ID  Gender    Salary  Age       City       Name  ID  \
# Employee_ID
# 101            Utkarsh   1    Male   95000.0   25     Jaipur    Utkarsh   1
# 102             Kartik   2    Male   85000.0   44      Delhi     Kartik   2
# 103          Aishwarya   3  Female   75000.0   42    Chennai  Aishwarya   3
# 104              Anand   4    Male   65000.0   36  Bangalore      Anand   4
# 105            Shalini   5  Female   90000.0   31     Jaipur    Shalini   5
# 106             Pratik   6    Male   80000.0   46    Gurgaon     Pratik   6
# 107           Monalika   7  Female   70000.0   29      Noida   Monalika   7
# 108             Ayesha   8  Female   60000.0   32      Noida     Ayesha   8
# 109              Anant   9    Male  100000.0   32  Hyderabad      Anant   9
# 110          Shamiksha  10  Female   45000.0   37      Delhi  Shamiksha  10
# 111           Prashant  11    Male   55000.0   28     Jaipur   Prashant  11
# 112             Mohini  12  Female   65000.0   34    Gurgaon     Mohini  12
# 115              Janki  15     NaN   85000.0   30    Karachi      Janki  15
# 116             Pratik  16     NaN       NaN   42  Dholakpur     Pratik  16
#
#              Gender    Salary  Age       City
# Employee_ID
# 101            Male   95000.0   25     Jaipur
# 102            Male   85000.0   44      Delhi
# 103          Female   75000.0   42    Chennai
# 104            Male   65000.0   36  Bangalore
# 105          Female   90000.0   31     Jaipur
# 106            Male   80000.0   46    Gurgaon
# 107          Female   70000.0   29      Noida
# 108          Female   60000.0   32      Noida
# 109            Male  100000.0   32  Hyderabad
# 110          Female   45000.0   37      Delhi
# 111            Male   55000.0   28     Jaipur
# 112          Female   65000.0   34    Gurgaon
# 115             NaN   85000.0   30    Karachi
# 116             NaN       NaN   42  Dholakpur

# %%
df1.Gender.value_counts()
# Out:
# Male      6
# Female    6
# Name: Gender, dtype: int64

# %%
df1.Gender.value_counts(normalize = True)
# Out:
# Male      0.5
# Female    0.5
# Name: Gender, dtype: float64

# %%
df1.Salary.value_counts()
# Out:
# 85000.0     2
# 65000.0     2
# 95000.0     1
# 75000.0     1
# 90000.0     1
# 80000.0     1
# 70000.0     1
# 60000.0     1
# 100000.0    1
# 45000.0     1
# 55000.0     1
# Name: Salary, dtype: int64

# %%
df1.City.value_counts()
# Out:
# Jaipur       3
# Delhi        2
# Gurgaon      2
# Noida        2
# Chennai      1
# Bangalore    1
# Hyderabad    1
# Karachi      1
# Dholakpur    1
# Name: City, dtype: int64

# %%
df1.describe()
# Out:
#               ID         Salary        Age
# count  14.000000      13.000000  14.000000
# mean    7.785714   74615.384615  34.857143
# std     4.660448   16388.707807   6.502747
# min     1.000000   45000.000000  25.000000
# 25%     4.250000   65000.000000  30.250000
# 50%     7.500000   75000.000000  33.000000
# 75%    10.750000   85000.000000  40.750000
# max    16.000000  100000.000000  46.000000

# %%
df1[['Age', 'Salary']].describe()
# Out:
#              Age         Salary
# count  14.000000      13.000000
# mean   34.857143   74615.384615
# std     6.502747   16388.707807
# min    25.000000   45000.000000
# 25%    30.250000   65000.000000
# 50%    33.000000   75000.000000
# 75%    40.750000   85000.000000
# max    46.000000  100000.000000

# %%
df1.count()
# Out:
# Name      14
# ID        14
# Gender    12
# Salary    13
# Age       14
# City      14
# dtype: int64

# %%
df1.mean()
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_15904/2053335143.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# ID            7.785714
# Salary    74615.384615
# Age          34.857143
# dtype: float64

# %%
df1.Salary.mean()
# Out:
# 74615.38461538461

# %%
df1.Age.mean()
# Out:
# 34.857142857142854

# %%
df1.std()
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_15904/3039516898.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.std()
# ID            4.660448
# Salary    16388.707807
# Age           6.502747
# dtype: float64

# %%
df1.Salary.std()
# Out:
# 16388.70780719894

# %%
df1.Salary.min()
# Out:
# 45000.0

# %%
df1.Age.min()
# Out:
# 25

# %%
df1.Salary.max()
# Out:
# 100000.0

# %%
df1.Age.max()
# Out:
# 46

# %%
df1.Salary.quantile(0.25)
# Out:
# 65000.0

# %%
df1.Salary.quantile(0.5)
# Out:
# 75000.0

# %%
df1.Salary.quantile(0.75)
# Out:
# 85000.0

# %%
df1.Salary.median()
# Out:
# 75000.0

# %%
df1.Age.median()
# Out:
# 33.0

# %%
df1.Age.mode()
# Out:
# 0    32
# 1    42
# dtype: int64
